# %% [markdown]
# # Notebook Overview

# %% [markdown]
# # Imports

# %%
from bs4 import BeautifulSoup # For Webscraping
import requests
import re

import pandas as pd

# %%
# # Import custom functions
# import sys
# sys.path.append('../')

# from custom_functions import functions_for_parsing

# %% [markdown]
# # Which pages are allowed?

# %%
# Find the url for next's robots.txt
robots_txt = 'https://www.next.co.uk/robots.txt'

# Get the text from robots.txt page
response = requests.get(robots_txt)
allow_and_disallow = response.text

# Create list of each line (string -> list)
allow_and_disallow = allow_and_disallow.split("\r\n")

# Filter for only pages that are allowed or disallowed
allow = [i for i in allow_and_disallow if i.startswith('Allow')]
disallow = [i for i in allow_and_disallow if i.startswith('Disallow')]

# Filter for only pages that are clothing
allow_clothing = [i for i in allow if not i.startswith('Allow: /homeware')]
allow_clothing = [i for i in allow_clothing if not i.startswith('Allow: /shop/department-homeware')]

# %%
def items_starting_with_string(_list, _string):
    '''Return items in list which begin with string'''
    return [i for i in _list if i.startswith(_string)]

def items_containing_string(_list, _string):
    '''Return items in list with the string'''
    return [i for i in _list if _string in i]

# %%
items_starting_with_string(disallow, 'Disallow: /shop/gender-men')
# Out:
# ['Disallow: /shop/gender-men-gender-women*',
#  'Disallow: /shop/gender-men-gender-oldergirls*',
#  'Disallow: /shop/gender-men-gender-youngergirls*',
#  'Disallow: /shop/gender-men-gender-women-gender-youngergirls*',
#  'Disallow: /shop/gender-men-gender-unisex*',
#  'Disallow: /shop/gender-men/*',
#  'Disallow: /shop/gender-men-productaffiliation-casualshirts*',
#  'Disallow: /shop/gender-men-productaffiliation-formalshirts*',
#  'Disallow: /shop/gender-men-productaffiliation-shirts*']

# %%
items_containing_string(disallow, 'sizetype')
# Out:
# ['Disallow: /shop/gender-*/sizetype-*sizetype*',
#  'Disallow: /shop/gender-women/sizetype-*/*',
#  'Disallow: /shop/sizetype-*/*sizetype-*',
#  'Disallow: /shop/*sizetype-*/*sizetype-*',
#  'Disallow: /shop/*-sizetype-*-sizetype-*',
#  'Disallow: /shop/sizetype-*-sizetype-*',
#  'Disallow: /shop/*/*-sizetype-*-sizetype-*',
#  'Disallow: /shop/*/sizetype-*-sizetype-*']

# %%
allow_clothing
# Out:
# ['Allow: /shop/gender-men-brand-nike-0$',
#  'Allow: /shop/gender-women-brand-nike-0$',
#  'Allow: /shop/gender-men-brand-adidas-0$',
#  'Allow: /shop/gender-women-brand-adidas-0$',
#  'Allow: /shop/gender-men-brand-converse-0$',
#  'Allow: /shop/gender-women-brand-converse-0$',
#  'Allow: /shop/gender-men-brand-skechers-0$',
#  'Allow: /shop/gender-women-brand-skechers-0$',
#  'Allow: /shop/gender-men-brand-underarmour-0$',
#  'Allow: /shop/gender-women-brand-underarmour-0$',
#  'Allow: /shop/gender-women-category-dresses/size-16$',
#  'Allow: /shop/gender-women-category-dresses/size-20$',
#  'Allow: /shop/gender-women-category-dresses/size-22$',
#  'Allow: /shop/gender-women-category-dresses/size-4$',
#  'Allow: /shop/gender-women-category-dresses/size-6$',
#  'Allow: /shop/gender-women-category-dresses/size-12$',
#  'Allow: /shop/gender-women-category-dresses/size-24$',
#  'Allow: /shop/gender-women-category-dresses/size-8$',
#  'Allow: /shop/gender-women-category-dresses/size-10$',
#  'Allow: /shop/gender-women-category-dresses/size-26$',
#  'Allow: /shop/gender-women-category-dresses/size-28$',
#  'Allow: /shop/gender-women/designfeature-christmassweater$',
#  'Allow: /shop/gender-men/designfeature-christmassweater$',
#  'Allow: /shop/department-childrenswear/designfeature-christmassweater$',
#  'Allow: /shop/gender-newborngirls-gender-newbornunisex-gender-oldergirls-gender-youngergirls/designfeature-christmassweater$',
#  'Allow: /shop/gender-newbornboys-gender-newbornunisex-gender-olderboys-gender-youngerboys/designfeature-christmassweater$ ',
#  'Allow: /shop/gender-men-productaffiliation-casualshirts/category-shirts$',
#  'Allow: /shop/gender-men-productaffiliation-formalshirts/category-shirts$',
#  'Allow: /shop/gender-women-category-dresses/size-18$',
#  'Allow: /shop/gender-women-productaffiliation-jumpsuitsandplaysuits/category-jumpsuit-size-18$',
#  'Allow: /shop/gender-women-productaffiliation-footwear/category-shoes-size-uk9eu43$',
#  'Allow: /shop/gender-women-category-dresses/size-14$',
#  'Allow: /shop/gender-women-productaffiliation-lingerie/category-bras-size-30dd$',
#  'Allow: /shop/*productaffiliation-holidayshop-0$',
#  'Allow: /shop/department-beauty-*-0',
#  'Allow: /shop/gender-women/brand-lipsy-sizetype-petite$',
#  'Allow: /shop/gender-women/brand-lipsy-sizetype-plussizes$',
#  'Allow: /shop/brand-*-0',
#  'Allow: /shop/category-dresses-brand-lipsy-0$',
#  'Allow: /shop/*/*brand-*',
#  'Allow: /shop/gender-women/feat-newin$',
#  'Allow: /shop/gender-oldergirls-gender-youngergirls/feat-newin$',
#  'Allow: /shop/gender-women-productaffiliation-tops/feat-newin$',
#  'Allow: /shop/gender-men/feat-newin$',
#  'Allow: /shop/gender-women/sizetype-*$',
#  'Allow: /shop/gender-men/sizetype-*$',
#  'Allow: /shop/productaffiliation-labelmix-editorial-label-0$',
#  'Allow: /shop/gender-men-category-trousers/designfeature-jeansstyle$',
#  'Allow: /shop/gender-men-category-trousers/colour-black-designfeature-jeansstyle$',
#  'Allow: /shop/gender-men-category-trousers/brand-next-designfeature-jeansstyle$',
#  'Allow: /women/casualwear/holiday-shop/1$',
#  'Allow: /women/tailored-looks/navy-yellow-workwear/1$',
#  'Allow: /boys/new-in/older-boys/1$',
#  'Allow: /women/nightwear/nightwear/1$',
#  'Allow: /men/tailoring/tailoring-essentials/1$']

# %% [markdown]
# Great pages to use:
# * `/shop/gender-women/sizetype-*$`
#     * [Link](https://www.next.co.uk/shop/gender-women/sizetype-)
#     * https://www.next.co.uk/shop/gender-men/sizetype-
# * `/shop/gender-men/sizetype-*$'` [Link](https://www.next.co.uk/shop/gender-men/sizetype-)

# %% [markdown]
# # Create Beautiful Soup Object

# %% [markdown]
# ## Test on Women's clothing

# %%
url_women = 'https://www.next.co.uk/shop/gender-women/sizetype-'

# %%
# Make a get request to retrieve the page
html_page = requests.get(url_women)

# Pass the page contents to beautiful soup for parsing
soup = BeautifulSoup(html_page.content, 'html.parser')

# %%
# Display the html code
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en-gb">
#  <head>
#   <link as="font" crossorigin="" href="//www.next.co.uk/content/Fonts/AzoSans-Regular-webfont.woff" rel="preload" type="font/woff"/>
#   <link as="font" crossorigin="" href="//www.next.co.uk/content/Fonts/AzoSans-Medium-webfont.woff" rel="preload" type="font/woff"/>
#   <link as="font" crossorigin="" href="//www.next.co.uk/content/Fonts/AzoSans-Light-webfont.woff" rel="preload" type="font/woff"/>
#   <link as="style" href="/CSS/fonts/Desktop/Fonts.min.css" rel="preload"/>
#   <link href="/CSS/fonts/Desktop/Fonts.min.css" rel="stylesheet"/>
#   <link as="font" href="/content/Fonts/AzoSans-Regular-webfont.woff" rel="preload" type="font/woff"/>
#   <link as="font" href="/content/Fonts/AzoSans-Medium-webfont.woff" rel="preload" type="font/woff"/>
#   <link as="script" href="https://xcdn.next.co.uk/content/platmod/vendors/react/16.13.1/umd/react.production.min.js" rel="preload"/>
#   <link as="script" href="https://xcdn.next.co.uk/content/platmod/vendors/react/16.13.1/umd/react-dom.production.min.js" rel="preload"/>
#   <link as="script" href="https://www.next.co.uk/footerstatic/static/js/2.1.5.11.chunk.js" rel="preload"/>
#   <link as="script" href="https://www.next.co.uk/footerstatic/static/js/main.1.5.11.chunk.js" rel="preload"/>
#   <script name="themeColours">
#    window.themeColours = window.themeColours || {};
#     window.themeColours["v5.3.0"] = {"form":{"buttonPrimary":{"border":"0","background":"#30a74b","color":"#ffffff","radius":"0.25rem"},"buttonSecondary":{"border":".0625rem solid #000000","background":"#ffffff","color":"#000000","radius":"0.25rem"},"buttonTertiary":{"border":"0","background":"#000000","color":"#ffffff","radius":"0.25rem"},"default":{"border":".0625rem solid #9e9e9e","background":"#ffffff","radius":"0.25rem"},"disabled":{"border":".0625rem solid #dedede","background":"#ffffff","radius":"0.25rem"},"focusActive":{"border":".0625rem solid #000000","background":"#ffffff","radius":"0.25rem"},"invalid":{"border":".0625rem solid #d91440","background":"#ffffff","radius":"0.25rem"},"selectedAccent":{"border":".125rem solid #257F39","background":"#ffffff","radius":"0.25rem"},"selectedBlock":{"border":".125rem solid #257F39","background":"rgba(255, 226, 216, 0.39)","radius":"0.25rem"},"success":{"border":".0625rem solid #109449","background":"#ffffff","radius":"0.25rem"}},"text":{"fontWeightRegular":400,"fontWeightMedium":500,"fontWeightBold":500,"default":"#000000","disabled":"#c5c5c5","reversed":"#ffffff","error":"#d91440","hyperlink":"#257f39","muted":"#515151","strong":"#000000","success":"#257f39","warning":"#d88f31","navigation":{"link":"#ffffff","linkActive":"#000000","linkClearance":"#f28500","fontWeight":500}},"footer":{"socialMedia":{"background":"initial"},"quickLinks":{"background":"#f7f7f7"},"mainLinks":{"background":"#f7f7f7"},"copyright":{"background":"#f7f7f7"}},"header":{"navUpperBackground":{"default":"#000000","color":"#ffffff"},"navLowerBackground":{"default":"#1e1e1e","desktop":"#000000","active":"#ffffff","border":"0"},"searchBar":{"radius":"0.25rem","color":"#000","border":"0.0625rem solid #eaeaea"},"shoppingBag":{"color":"#fff"},"myAccount":{"background":"#fff","radius":"0.25rem"}},"utilities":{"divider":"0.0625rem solid #eaeaea","dividerDark":".0625rem solid #9e9e9e","backgroundAccent":"#f7f7f7","activeBorder":"0.125rem solid #257f39","chipBorderRadius":"0.25rem"},"drawer":{"headerBackground":"#f7f7f7","headerBorder":".0625rem solid #9e9e9e"},"plp":{"layout":{"flexDirection":"initial","hasColourChips":"","hasBrandName":"none"},"listing":{"textAlign":"left"}}}
#   </script>
#   <style name="font-ssr-styles">
#    @font-face {
#       font-family: AzoSansRegular;
#       src: url("/content/Fonts/AzoSans-Regular-webfont.woff") format("woff");
#   }
#   @font-face {
#       font-family: AzoSansMedium;
#       src: url("/content/Fonts/AzoSans-Medium-webfont.woff") format("woff");
#       font-weight: bold;
#   }
#   </style>
#   <noscript id="jss-insertion-point">
#   </noscript>
#   <!-- pageframe -->
#   <!-- DataLayer -->
#   <script type="text/javascript">
#    var dataLayer = dataLayer || [];
#     var overrideROWCountryCode = document.getElementById('header_header-icon-country-select') == null ? null : document.getElementById('header_header-icon-country-select').getAttribute("rowcountrycode");
#     var countryCode = overrideROWCountryCode !== null ? overrideROWCountryCode : "GB";
#     dataLayer.push({ 'page_type': 'productListPage' });
#     dataLayer.push({ 'device_type': 'desktop' });
#
#     dataLayer.push({
#             'pageType': 'productListPage',
#             'siteLayout': 'desktop',
#             'SoftwareVersion': '2020.1118.500.4',
#             'siteCountry': countryCode,
#             'siteLanguage': 'en'
#     });
#
#     dataLayer.push({ 'br_pot_id': '' });
#     if ('False' == 'True') {
#         dataLayer.push({ 'br_rpid': '' });
#     }
#
#     var rpid = window.sessionStorage.getItem("RPID");
#     var acctType = window.sessionStorage.getItem("AcctType");
#     var unlimtedCustomer = window.sessionStorage.getItem("unlimitedCustomer");
#     var userVariables = null;
#     if (rpid) {
#         userVariables = {
#             'event': 'user variables', //allows gtm to identify the dataLayer.push
#             'userId': rpid
#         }
#         if (acctType && unlimtedCustomer) {
#             userVariables.unlimitedCustomer = (unlimtedCustomer == 'true');
#             userVariables.accountType = acctType;
#         }
#
#     }
#     if (userVariables) {
#         dataLayer.push(userVariables);
#
#     }
#     var MobileSiteUri = '//www.next.co.uk';
#     var SecureMobileSiteUri = 'https://www.next.co.uk';
#     var CdnBaseUrl = 'https://xcdn.next.co.uk';
#     var ItemLevelImagery = 'true';
#   </script>
#   <!-- Begin Monetate ExpressTag Sync v8.1. Place at start of document head. DO NOT ALTER. -->
#   <script type="text/javascript">
#    var monetateT = new Date().getTime();
#   </script>
#   <script src="//se.monetate.net/js/2/a-4295dd5d/p/www.next.co.uk/entry.js" type="text/javascript">
#   </script>
#   <!-- End Monetate tag. -->
#   <!-- MonetateQ -->
#   <script type="text/javascript">
#    window.monetateQ = window.monetateQ || [];
#         window.monetateQ.push(["setPageType", "productListPage"]);
#             if (dataLayer != undefined) {
#             dataLayer.push({ 'monetate_enabled': 'true' });
#              }
#   </script>
#   <script type="text/javascript">
#    if (dataLayer != undefined) {
#             dataLayer.push({ 'br_pixel_enabled': 'true' });
#             dataLayer.push({ 'br_view_id': 'gb' });
#             dataLayer.push({ 'br_domain_key': 'next' });
#         }
#   </script>
#   <meta charset="utf-8"/>
#   <title>
#    Buy  Women's  from the Next UK online shop
#   </title>
#   <meta content="Next,next.co.uk,Next Directory,Next Flowers,Next Electrics,fashion,clothes,womens,mens,childrens,home,furniture" name="keywords"/>
#   <meta content="Shop for  Women's at Next.co.uk. Next day delivery and free returns available. 1000s of products online. Buy  Women's now!" name="description"/>
#   <link href="/humans.txt" rel="publisher"/>
#   <meta content="Next Retail Limited" name="author"/>
#   <!-- Facebook URL Linter Setup -->
#   <!--meta name="og:title" content="Buy  Women&#39;s  from the Next UK online shop"/> - Not Valid in HTML5 -->
#   <!--meta name="og:site_name" content="next.co.uk"/> - Not Valid in HTML5 -->
#   <!-- Icons -->
#   <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <link href="/favicon.ico" rel="icon" type="image/x-icon"/>
#   <link href="/Images/Mobile/iOS/icons/app_icon_57x57.png" rel="apple-touch-icon-precomposed" sizes="57x57"/>
#   <link href="/Images/Mobile/iOS/icons/app_icon_60x60.png" rel="apple-touch-icon-precomposed" sizes="60x60"/>
#   <link href="/Images/Mobile/iOS/icons/app_icon_72x72.png" rel="apple-touch-icon-precomposed" sizes="72x72"/>
#   <link href="/Images/Mobile/iOS/icons/app_icon_76x76.png" rel="apple-touch-icon-precomposed" sizes="76x76"/>
#   <link href="/Images/Mobile/iOS/icons/app_icon_114x114.png" rel="apple-touch-icon-precomposed" sizes="114x114"/>
#   <link href="/Images/Mobile/iOS/icons/app_icon_120x120.png" rel="apple-touch-icon-precomposed" sizes="120x120"/>
#   <link href="/Images/Mobile/iOS/icons/app_icon_144x144.png" rel="apple-touch-icon-precomposed" sizes="144x144"/>
#   <link href="/Images/Mobile/iOS/icons-bookmark/apple-touch-icon-180x180.png" rel="apple-touch-icon-precomposed" sizes="180x180"/>
#   <!-- iPhone SPLASHSCREEN-->
#   <link href="/Images/mobile/iOS/ios-app-splashscreen/splashscreen_640x920.png" media="(device-width: 320px)" rel="apple-touch-startup-image"/>
#   <!-- iPhone (Retina) SPLASHSCREEN-->
#   <link href="/Images/mobile/iOS/ios-app-splashscreen/splashscreen_640x920.png" media="(device-width: 320px) and (device-height: 460px) and (-webkit-device-pixel-ratio: 2)" rel="apple-touch-startup-image"/>
#   <!-- iPhone 5 (Retina) SPLASHSCREEN-->
#   <link href="/Images/mobile/iOS/ios-app-splashscreen/splashscreen_640x1096.png" media="(device-width: 320px) and (device-height: 568px) and (-webkit-device-pixel-ratio: 2)" rel="apple-touch-startup-image"/>
#   <!-- iPad (non-Retina) (Portrait) -->
#   <link href="/Images/mobile/iOS/ios-app-splashscreen/splashscreen_768x1004.png" media="screen and (min-device-width: 481px) and (max-device-width: 1024px) and (orientation:portrait)" rel="apple-touch-startup-image">
#    <!-- iPad (non-Retina) (Landscape) -->
#    <link href="/Images/mobile/iOS/ios-app-splashscreen/splashscreen_1024x748.png" media="screen and (min-device-width: 481px) and (max-device-width: 1024px) and (orientation:landscape)" rel="apple-touch-startup-image">
#     <!-- iPad (Retina) (Portrait) -->
#     <link href="/Images/mobile/iOS/ios-app-splashscreen/splashscreen_1536x2008.png" media="screen and (min-device-width: 481px) and (max-device-width: 1024px) and (orientation:portrait) and (-webkit-min-device-pixel-ratio: 2)" rel="apple-touch-startup-image">
#      <!-- iPad (Retina) (Landscape) -->
#      <link href="/Images/mobile/iOS/ios-app-splashscreen/splashscreen_2048x1496.png" media="screen and (min-device-width: 481px) and (max-device-width: 1024px) and (orientation:landscape) and (-webkit-min-device-pixel-ratio: 2)" rel="apple-touch-startup-image"/>
#      <!-- iphone6 SPLASHSCREEN-->
#      <link href="/Images/mobile/iOS/ios-app-splashscreen/splashscreen_750x1294.png" media="(device-width: 375px) and (device-height: 667px) and (-webkit-device-pixel-ratio: 3)" rel="apple-touch-startup-image"/>
#      <!-- iphone6 plus portrait SPLASHSCREEN-->
#      <link href="/Images/mobile/iOS/ios-app-splashscreen/splashscreen_1242x2148.png" media="(device-width: 414px) and (device-height: 736px) and (-webkit-device-pixel-ratio: 3) and (orientation: portrait)" rel="apple-touch-startup-image"/>
#      <!-- iphone6 plus landscape SPLASHSCREEN-->
#      <link href="/Images/mobile/iOS/ios-app-splashscreen/splashscreen_1182x2208.png" media="(device-width: 414px) and (device-height: 736px) and (-webkit-device-pixel-ratio: 3) and (orientation: landscape)" rel="apple-touch-startup-image"/>
#      <meta content="Next" name="apple-mobile-web-app-title"/>
#      <meta content="yes" name="apple-mobile-web-app-capable"/>
#      <link href="/css/bundles/modular/preload-responsive.css?v=CcOKVBrKncDAFuSivJ6-NTRjhS6yaI6Mf6LfceFV75w1?v=2020.1118.500.4" rel="Stylesheet">
#       <link href="/CSS/SASS/Gel-3.0/Desktop/header.min.css?v=2020.1118.500.4" rel="Stylesheet">
#        <link href="/CSS/SASS/Gel-3.0/Desktop/product-list-page.min.css?v=2020.1118.500.4" rel="Stylesheet">
#         <link href="https://www.next.co.uk/shop/gender-women/sizetype-" rel="canonical"/>
#         <link href="//www.next.co.uk/shop/gender-women/sizetype--srt-24" rel="next"/>
#         <!-- This script file makes older versions of IE aware of the new HTML5 elements so that it can attempt to render them in the HTML4 renderer  -->
#         <!--[if lt IE 9]><script src="/Scripts/HTML5Shiv.js?v=2020.1118.500.4"></script><![endif]-->
#         <meta content="width=976" name="viewport"/>
#         <script>
#          function setViewport() {
#                 if (screen.width >= 976) {
#                     viewport = document.querySelector("meta[name=viewport]");
#                     viewport.setAttribute('content', 'width=976, initial-scale=1.0');
#                 }
#             }
#         </script>
#         <script>
#          !function(a){var e="https://s.go-mpulse.net/boomerang/",t="addEventListener";if("False"=="True")a.BOOMR_config=a.BOOMR_config||{},a.BOOMR_config.PageParams=a.BOOMR_config.PageParams||{},a.BOOMR_config.PageParams.pci=!0,e="https://s2.go-mpulse.net/boomerang/";if(window.BOOMR_API_key="TNQA3-QZTH5-DLFR3-LEWEU-2BUJP",function(){function n(e){a.BOOMR_onload=e&&e.timeStamp||(new Date).getTime()}if(!a.BOOMR||!a.BOOMR.version&&!a.BOOMR.snippetExecuted){a.BOOMR=a.BOOMR||{},a.BOOMR.snippetExecuted=!0;var i,_,o,r=document.createElement("iframe");if(a[t])a[t]("load",n,!1);else if(a.attachEvent)a.attachEvent("onload",n);r.src="javascript:void(0)",r.title="",r.role="presentation",(r.frameElement||r).style.cssText="width:0;height:0;border:0;display:none;",o=document.getElementsByTagName("script")[0],o.parentNode.insertBefore(r,o);try{_=r.contentWindow.document}catch(O){i=document.domain,r.src="javascript:var d=document.open();d.domain='"+i+"';void(0);",_=r.contentWindow.document}_.open()._l=function(){var a=this.createElement("script");if(i)this.domain=i;a.id="boomr-if-as",a.src=e+"TNQA3-QZTH5-DLFR3-LEWEU-2BUJP",BOOMR_lstart=(new Date).getTime(),this.body.appendChild(a)},_.write("<bo"+'dy onload="document._l();">'),_.close()}}(),"".length>0)if(a&&"performance"in a&&a.performance&&"function"==typeof a.performance.setResourceTimingBufferSize)a.performance.setResourceTimingBufferSize();!function(){if(BOOMR=a.BOOMR||{},BOOMR.plugins=BOOMR.plugins||{},!BOOMR.plugins.AK){var e=""=="true"?1:0,t="",n="jbjvprixan57yx6gxguq-f-aaf40c7c4-clientnsv4-s.akamaihd.net",i={"ak.v":"29","ak.cp":"108788","ak.ai":parseInt("421063",10),"ak.ol":"0","ak.cr":18,"ak.ipv":4,"ak.proto":"http/1.1","ak.rid":"150255ef","ak.r":33993,"ak.a2":e,"ak.m":"b","ak.n":"essl","ak.bpcip":"72.83.87.0","ak.cport":54664,"ak.gh":"23.36.1.38","ak.quicv":"","ak.tlsv":"tls1.2","ak.0rtt":"","ak.csrc":"-","ak.acc":"reno","ak.t":"1606859177","ak.ak":"hOBiQwZUYzCg5VSAfCLimQ==...","ak.pv":"97","ak.dpoabenc":""};if(""!==t)i["ak.ruds"]=t;var _={i:!1,av:function(e){var t="http.initiator";if(e&&(!e[t]||"spa_hard"===e[t]))i["ak.feo"]=void 0!==a.aFeoApplied?1:0,BOOMR.addVar(i)},rv:function(){var a=["ak.bpcip","ak.cport","ak.cr","ak.csrc","ak.gh","ak.ipv","ak.m","ak.n","ak.ol","ak.proto","ak.quicv","ak.tlsv","ak.0rtt","ak.r","ak.acc","ak.t"];BOOMR.removeVar(a)}};BOOMR.plugins.AK={akVars:i,akDNSPreFetchDomain:n,init:function(){if(!_.i){var a=BOOMR.subscribe;a("before_beacon",_.av,null,null),a("onbeacon",_.rv,null,null),_.i=!0}return this},is_complete:function(){return!0}}}}()}(window);
#         </script>
#        </link>
#       </link>
#      </link>
#     </link>
#    </link>
#   </link>
#  </head>
#  <body class="font-antialiased bp1280 bp1440" data-country="GB" data-theme="" style="overflow-y:scroll;">
#   <input class="br_data-taxonomy-enabled" hidden="" title="no informative content" value="False"/>
#   <input class="br_data-sofa-cat_id" hidden="" title="no informative content" value="474"/>
#   <input class="br_data-sofa-cat" hidden="" title="no informative content" value="Home|Home|Sofa Collections"/>
#   <a -accessibility="" data="" href="https://accessible.next.co.uk/" style="position: absolute; width: 1px; height: 1px; margin: -1px; padding: 0; overflow: hidden; clip: rect(0,0,0,0); border: 0">
#    Click here to use our accessible website
#   </a>
#   <script type="text/javascript">
#    var searchTrackingDisabled = "";
#         var resultCount = "";
#         var globalNextSaleCookieDomain = '';
#         var PersonalisationApiUrl = 'https://www.next.co.uk/api/personalisation/v0/gb/en-gb';
#         var PersonalisationExpiryInMinutes = 43200;
#         var PersonalisationClientOnly = true;
#
#         var lazyLoadEnabled = 'True';
#         var lazyLoadSearchEnabled = 'True';
#         var lazyLoadUseSettings = 'True';
#
#         if (lazyLoadEnabled == 'True' || lazyLoadSearchEnabled == 'True') {
#             window.lazySizesConfig = window.lazySizesConfig || {};
#
#             var isPLP = false;
#             if (dataLayer && Array.isArray(dataLayer)) {
#                 isPLP = dataLayer.some(function (dataLayerElem) {
#                     return (dataLayerElem.page_type == "searchResults" || dataLayerElem.page_type == "productListPage");
#                 });
#             }
#
#             if (isPLP && lazyLoadUseSettings == 'True') {
#                 updateLazyLoadExpand();
#                 window.addEventListener("load", updateLazyLoadExpand)
#                 window.addEventListener("resize", updateLazyLoadExpand)
#             }
#             else {
#                 window.lazySizesConfig.expFactor = 1.2;
#                 window.lazySizesConfig.expand = 100;
#             }
#         }
#
#         function updateLazyLoadExpand() {
#             var article = document.getElementsByTagName("article")[0];
#             var articleHeight = 0;
#
#             window.lazySizesConfig.expFactor = 1;
#             window.lazySizesConfig.loadMode = 2;
#
#             articleHeight = article != null ? Math.ceil(article.offsetHeight) : Math.ceil(405);
#
#             var expand = Math.max(0,
#                 (articleHeight * 4
#                 + 250) - window.outerHeight);
#
#             window.lazySizesConfig.expand = expand;
#         }
#   </script>
#   <script type="text/javascript">
#    var globalNextSaleCookieDomain = '';
#   </script>
#   <script src="/scripts/bundles/preabdependencies.js?v=YQfXR5k_JSEmg3yVDUcS_yJ7qyJep0_Ul6Db6laI18Q1?v=2020.1118.500.4" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    var ABPlatformCookieDomain = '';
#   </script>
#   <script type="text/javascript">
#    var ABPlatformCookie = '.next.co.uk';
#   </script>
#   <script src="https://xcdn.next.co.uk/ABPlatform/Scripts/ABCPlatformConfigSettings_v2.js" type="text/javascript">
#   </script>
#   <script src="/scripts/abplatform.js?v=2020.1118.500.4" type="text/javascript">
#   </script>
#   <script src="/scripts/bundles/prerender.js?v=DKnq6IT0pl0yGI_9KLgkCwY6o5Zda2Hq6O88-1Q43t81?v=2020.1118.500.4" type="text/javascript">
#   </script>
#   <div id="fb-root">
#   </div>
#   <script type="text/javascript">
#    var cdnURL = 'https://xcdn.next.co.uk';
#       var GAEnabled = 'false';
#       var GAAccount = '';
#       var NextTrialEnabled = 'true';
#       var pageLoadStart = new Date().getTime();
#
#       var LabelURL = '';
#   </script>
#   <script type="text/javascript">
#    /* Base for the website depending on the SecureAssets mode */var siteAssetsUrl = '//www.next.co.uk';/* Base for the HTTP version of the website */var siteBaseUrl = '//www.next.co.uk';/* Base for the HTTPS version of the website */var secureSiteBaseUrl = 'https://www.next.co.uk';/* Base for the Lists website used for Recently Viewed */var ListsURL = '//www.next.co.uk/lists';/* Base for the secure Lists website used for Recently Viewed */var SecureListsURL = '//www.next.co.uk/lists';
#   </script>
#   <header class="PageHeader font-antialiased JumpFix">
#    <div class="HeaderContent">
#     <section class="HeaderTopBar Content">
#      <div class="helper">
#       Next.co.uk
#      </div>
#      <a accesskey="o" class="SiteLogo gold" data-link-id="01-01" href="//www.next.co.uk/" id="header-logo" title="Go to the  homepage for clothes &amp; more">
#      </a>
#      <div class="flagSelectorContainer withLightBox" id="headerFlagSelector">
#       <div class="flagContainer">
#        <div class="HeaderFlag flagBackground flag-UnitedKingdom">
#        </div>
#       </div>
#       <div class="tooltipContainer">
#        <div class="topArrow">
#        </div>
#        <div class="tooltip">
#         <div class="">
#          <div class="tooltipMessage">
#           Click here to change your country and language
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="countrySelector">
#        <div class="rightPane">
#         <p class="title">
#          Shop By Country
#         </p>
#         <div class="paneContent">
#          <div class="section">
#           <label class="country">
#            Location
#           </label>
#           <select class="selectorDropdown countrySelectDD" data-customdropdown="true" id="countrySelectorDropdown" name="countrySelectorDropdown">
#           </select>
#          </div>
#          <div class="section">
#           <label class="languageLabel hidden">
#            Language
#           </label>
#           <br/>
#           <div class="languageButtons">
#           </div>
#           <div class="languageList">
#            <select class="selectorDropdown languageSelectDD" data-customdropdown="true" id="languageSelectorDropdown" name="languageSelectorDropdown">
#            </select>
#           </div>
#          </div>
#          <div class="bottomSection">
#           <div class="shopNow">
#            <a class="btnFlagSelectorShopNow disabled" href="" id="btnFlagSelectorShopNow">
#             SHOP NOW
#            </a>
#            <a class="stayOnNext" href="">
#             Stay on next.co.uk
#            </a>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="Checkout">
#       <a class="nxbtn primary disabled" data-link-id="01-08" data-link-name="Checkout" href="//www.next.co.uk/shoppingbag" onclick="TrackLinkID(this);" rel="nofollow">
#        Checkout
#       </a>
#      </div>
#      <section class="BagSummary MiniBagNonSecure">
#       <a data-link-id="01-07" data-link-name="Shopping Bag" href="//www.next.co.uk/shoppingbag" rel="nofollow">
#        <div class="Icon">
#         <svg id="gel-bag-summary" style="display: none">
#          <use xlink:href="/images/gel3-0/next-gel-3-sprites-min.svg#icon-outline-bag" xmlns:xlink="http://www.w3.org/1999/xlink">
#          </use>
#         </svg>
#         <div class="ItemCount">
#          <span>
#          </span>
#         </div>
#        </div>
#        <div class="BagTextClipping nextDisplayNone">
#         <div class="BagSummaryText" id="bagtext">
#         </div>
#        </div>
#        <div class="ClearBoth">
#        </div>
#       </a>
#      </section>
#      <section class="QuickLinks">
#       <ul>
#        <li class="nodisplay" data-section="myAccount">
#         <a accesskey="h" data-external="DataExternal" data-link-id="DataLinkId" data-link-name="DataLinkName" href="//www.next.co.uk/secure/accounts/transfer" onclick="TrackLinkID(this);" rel="nofollow" title="Sign in to view account details">
#          My Account
#         </a>
#        </li>
#        <li>
#         <a data-link-type="helpsite" href="/help/" rel="nofollow" title="Help - FAQ's, how to shop online, sizing guides and more">
#          Help
#         </a>
#        </li>
#        <li>
#         <a href="//www.next.co.uk/stores/" rel="nofollow" title="Find your nearest Next Store">
#          Store Locator
#         </a>
#        </li>
#        <li>
#         <a href="//www.next.co.uk/quickshop" rel="nofollow" title="Quickshop">
#          Quickshop
#         </a>
#        </li>
#       </ul>
#      </section>
#      <section class="Search">
#       <form action="//www.next.co.uk/search" data-link-id="01-06" data-link-name="Search" id="newsearch" method="get" name="newsearch" onsubmit="TrackLinkID(this);">
#        <div class="helper">
#         <label for="sli_search_1">
#          Search:
#         </label>
#        </div>
#        <input autocomplete="off" class="SearchBox" id="sli_search_1" name="w" placeholder="Search product or brand" required="required" spellcheck="false" type="text" value=""/>
#        <input name="isort" type="hidden" value="score"/>
#        <input id="search-af" name="af" type="hidden"/>
#        <input class="SearchButton" title="Search Items" type="submit" value=""/>
#        <div class="search-dropdown-container">
#         <div class="search-dropdown-content">
#          <ul class="search dropdown">
#           <!-- DO NOT REMOVE -->
#          </ul>
#          <div class="search-dropdown-products">
#           <div class="search-dropdown-products__heading">
#            <!-- DO NOT REMOVE -->
#           </div>
#           <div class="search-dropdown-products__list">
#            <!-- DO NOT REMOVE -->
#           </div>
#          </div>
#         </div>
#        </div>
#       </form>
#      </section>
#     </section>
#     <nav class="HeaderNavigation" id="MainNavigation">
#      <div class="Content MainNavigation MegaNavEnabledNavigation">
#       <ul class="PrimaryNavigation Standard">
#       </ul>
#      </div>
#      <!--
#                 SecureAssets: false-->
#     </nav>
#     <div class="menu-overlay">
#     </div>
#    </div>
#    <section class="BreadcrumbNavigation">
#     <section class="NavigationFadeSection">
#      <div class="NavigationFade">
#      </div>
#     </section>
#     <div class="Content">
#      <section class="Back">
#       <a class="nxbtn icon icon-arrow-left" onclick="GoBackOrClose();">
#        Back
#       </a>
#      </section>
#      <section class="Breadcrumbs">
#       <div class="BreadcrumbsHolder">
#        <ul class="Breadcrumbs">
#         <li class="Breadcrumb bcHome">
#          <a href="//www.next.co.uk/" onclick="this.blur();TrackLinkID(this);">
#           Home
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="BreadcrumbEllipsis">
#        …
#       </div>
#      </section>
#      <div class="ClearBoth">
#      </div>
#     </div>
#    </section>
#   </header>
#   <hr class="helper"/>
#   <div id="tempSEONavigation" style="display:none">
#    <style>
#     .HeaderDesktopNavigation {width: 100%;height: 37px;z-index: 1050;}body[data-theme='Childsplay'] .PageHeader .HeaderContent{height:108px !important;}.MainDesktopNavigation .PrimaryDesktopNavigation .Primarynavlinks {display: block;list-style: none;height: 35px;padding: 0;}.MainDesktopNavigation .SecondaryDesktopNavigation.NavLoader{height:384px;}.NavLoader img.placeholderNavLoader{position: relative;top: 50%;left: 50%;margin-top: -19px;margin-left: -19px;background-image:width: 34px;height: 34px;}.NavLoader .defaultLoader{content: '';border-radius: 100%;animation: spin 0.6s infinite linear;border: 2px solid rgba(255, 255, 255, 0.05);border-left-color: #000000;border-top-color: #000000;width: 34px;height: 34px;position: absolute;left: calc(50% - 17px);top: calc(50% - 17px);background: none;}.HeaderDesktopNavigation .NavContent.MainDesktopNavigation ul.PrimaryDesktopNavigation {box-sizing: border-box;text-align: left;}.MainDesktopNavigation li {list-style: none;}body.msie8 .MainDesktopNavigation .PrimaryDesktopNavigation .Primarynavlinks {display: table-cell}.PrimaryFixWidth .MainDesktopNavigation .PrimaryDesktopNavigation .Primarynavlinks {margin-right: 0;}.MainDesktopNavigation .PrimaryDesktopNavigation .Primarynavlinks.Last {margin-right: 0;}.MainDesktopNavigation .PrimaryDesktopNavigation .Primarynavlinks .PrimarynavlinksText {padding: 7px 5px 2px 5px;margin-right: 2px;display: block;position: relative;z-index: 1000;cursor: pointer;}.HeaderDesktopNavigation span.PrimarynavlinksText {white-space: nowrap;}.PrimaryFixWidth .MainDesktopNavigation .PrimaryDesktopNavigation .Primarynavlinks .PrimarynavlinksText {padding-left: 14px;padding-right: 14px;}.msie6 .MainDesktopNavigation .PrimaryDesktopNavigation .Primarynavlinks .PrimarynavlinksText {padding: 7px 7px 0 7px;}.MainDesktopNavigation .PrimaryDesktopNavigation .Primarynavlinks .PrimarynavlinksText:after {display: block;content: '';border-bottom: 1px solid transparent;padding-top: 2px;}.MainDesktopNavigation .PrimaryDesktopNavigation .Primarynavlinks a.PrimarynavlinksLink {text-align: center;text-decoration: none;display: block;height: 37px;color: white;transition-delay: .35s;}.MainDesktopNavigation .PrimaryDesktopNavigation .Primarynavlinks a.PrimarynavlinksLink:hover {color: #111!important;background: #fff;padding-bottom: 1px;}.LinkActive {color: #111!important;background: #fff;padding-bottom: 1px;}.MainDesktopNavigation .SecondaryDesktopNavigation {background-color: #fff;border-bottom: 1px solid #c7c5c5;font-size: 12px;height: auto;max-height: none;border-top: none;overflow: hidden;zoom: 1;}.MainDesktopNavigation {height: 37px;margin: 0 auto;font-family: 'azo-sans', sans-serif;font-weight: 400;font-size: 14px;letter-spacing: -.1px;position: relative;}.MainDesktopNavigation .PrimaryDesktopNavigation {margin: 0;width: 100%;height: 37px;display: -webkit-box;display: -ms-flexbox;display: -webkit-flex;display: flex;-webkit-box-pack: justify;-ms-flex-pack: justify;justify-content: space-between;padding-left: 1px;zoom: 1;}.SNDefaultNAV {width: 100%;position: absolute;top: -1000px;left: -9999px;opacity: 0;}.Left-Aligned .PrimaryDesktopNavigation {display: block !important;}.Left-Aligned .PrimaryDesktopNavigation .Primarynavlinks {float: left !important;}.Center-Aligned .PrimaryDesktopNavigation {display: block !important;text-align: center !important;}.Center-Aligned .PrimaryDesktopNavigation .Primarynavlinks {display: inline-block !important;}.mobElemOnly {display: none !important;}@media(min-width:1280px) {.SNDefaultNAV {width: 1270px;}}.SNSNavHover {top: 37px;left: 1px;opacity: 1;}.MainDesktopNavigation .PrimaryDesktopNavigation body.msie8 {display: table;}.MainDesktopNavigation .PrimaryDesktopNavigation li.Active div.SecondaryDesktopNavigation {z-index: 9999;}.MainDesktopNavigation .SecondaryDesktopNavigation .NavContentContainer {border: none;color: #222;}.MainDesktopNavigation .SecondaryDesktopNavigation .NavContentContainer .column .LinksHeader:first-child {padding-top:  ...
#    </style>
#    <script>
#     document.addEventListener('DOMContentLoaded', function (event) {var isDeviceTouchEnabled = false;var isSecondaryNavOpen = false;var hoverInTimer;var ulHovered = $('.MainDesktopNavigation .PrimaryDesktopNavigation');var menuoverlay = $('.menu-overlay');var locale = $('#MainDesktopNavigation').attr('data-locale');var sitename = $('#MainDesktopNavigation').attr('data-site');if ((typeof (navigator.maxTouchPoints) == 'undefined')) {if ((typeof (window.ontouchstart) != 'undefined')) {isDeviceTouchEnabled = true;} else if (navigator.msMaxTouchPoints > 0) {isDeviceTouchEnabled = true;}} else if (navigator.maxTouchPoints > 0) {isDeviceTouchEnabled = true;}ulHovered.hover(function () {ulHovered.addClass('UlHovered');},function () {ulHovered.removeClass('UlHovered');});$('.Primarynavlinks').each(function () {var liPrimaryNav = $(this);var secondaryNav = $(this).children('.SecondaryDesktopNavigation');var activeLink = $(this).children('.PrimarynavlinksLink');if (!isDeviceTouchEnabled) {$(this).hover(function () {menuHoverIn(liPrimaryNav, activeLink, secondaryNav);},function (e) {liPrimaryNav.removeClass('Hovered');activeLink.removeClass('LinkActive');clearTimeout(hoverInTimer);closeSecondaryNavPanel(activeLink, secondaryNav);});} else {$(this).click(function (event) {if ($(event.target).hasClass('PrimarynavlinksText')) {closeActiveSecondaryNavForTouchDevices();menuHoverIn(liPrimaryNav, activeLink, secondaryNav);return false;}});}});$('.SecondaryDesktopNavigation .NavContentContainer').each(function () {if (!($(this).hasClass('MissionBlockSingle') || $(this).hasClass('MissionBlockDouble'))) {if ($(this).children('ul').length <= 3) {$(this).parent('.SecondaryDesktopNavigation').addClass('nav-reduced-width');}}});if (isDeviceTouchEnabled) {menuoverlay.click(function () {closeActiveSecondaryNavForTouchDevices();menuoverlay.removeClass('active');});}function menuHoverIn(liPrimaryNav, activeLink, secondaryNav) {liPrimaryNav.addClass('Hovered');activeLink.addClass('LinkActive');hoverInTimer = setTimeout(function () {if (liPrimaryNav.hasClass('Hovered') && activeLink.hasClass('LinkActive')) {openSecondaryNavPanel(secondaryNav);if(secondaryNav.hasClass('hideMenuOverLay')){$('.menu-overlay').removeClass('active');} else {handleMenuOverlay(true, null);}}}, 350);}function openSecondaryNavPanel(val) {if (!val.hasClass('SecNavLoaded')) {fetchSecondaryNavContent(val);}$('.PrimarynavlinksLink.LinkActive').each(function () {var secondaryNav = $(this).siblings('div.SecondaryDesktopNavigation');closeSecondaryNavPanel($(this), secondaryNav);});val.addClass('Active');val.addClass('SNSNavHover');isSecondaryNavOpen = true;}function closeSecondaryNavPanel(activeLink, val) {var liPrimary = val.parent();if (liPrimary.hasClass('Hovered') && activeLink.hasClass('LinkActive')) {return false;} else if (ulHovered.hasClass('UlHovered')) {return setTimeout(function () {val.removeClass('SNSNavHover');val.removeClass('Active');handleMenuOverlay(false, null);}, 350);} else {val.removeClass('SNSNavHover');val.removeClass('Active');handleMenuOverlay(false, null);return true;}}function handleMenuOverlay(toggle, activeLink) {if(toggle){if(locale=='en_GB'){menuoverlay.addClass('active');menuoverlay.css('height', document.body.scrollHeight);}}else{if($('.PrimaryDesktopNavigation .PrimarynavlinksLink.LinkActive').length == 0){$('.menu-overlay').removeClass('active');}}}function closeActiveSecondaryNavForTouchDevices() {if (isSecondaryNavOpen) {if ($('div.MainDesktopNavigation').children('ul.PrimaryDesktopNavigation').children('li.Primarynavlinks.Hovered').length > 0) {var element = $('div.MainDesktopNavigation').children('ul.PrimaryDesktopNavigation').children('li.Primarynavlinks.Hovered');element.removeClass('Hovered');element.children('.PrimarynavlinksLink').removeClass('LinkActive');return setTimeout(function () {element.children('div.SecondaryDesktopNavigation').removeClass('SNSNavHover');element.children('div.SecondaryDesktopNavigation').removeClass('Active');isSecondaryN ...
#    </script>
#    <nav class="HeaderDesktopNavigation next" data-locale="en_GB" data-site="next" id="MainDesktopNavigation" style="background-color: black;">
#     <div class="NavContent MainDesktopNavigation">
#      <ul class="PrimaryDesktopNavigation">
#       <li class="Primarynavlinks" data-department="CHRISTMAS">
#        <a class="PrimarynavlinksLink" data-link-id="02-01" data-link-name="CHRISTMAS" href="/christmas" id="NI1" onclick="this.blur();TrackLinkID(this);" title="CHRISTMAS">
#         <span class="PrimarynavlinksText" style="font-weight:bold!important;color:#B78B1F;">
#          CHRISTMAS
#         </span>
#        </a>
#        <div class="SecondaryDesktopNavigation SNDefaultNAV NavLoader nav-align-left" data-parentname="CHRISTMAS">
#         <div class="defaultLoader">
#         </div>
#        </div>
#       </li>
#       <li class="Primarynavlinks" data-department="WOMEN">
#        <a class="PrimarynavlinksLink" data-link-id="02-02" data-link-name="WOMEN" href="/women" id="NI2" onclick="this.blur();TrackLinkID(this);" title="WOMEN">
#         <span class="PrimarynavlinksText" style="font-weight:bold!important;">
#          WOMEN
#         </span>
#        </a>
#        <div class="SecondaryDesktopNavigation SNDefaultNAV NavLoader nav-align-left" data-parentname="WOMEN">
#         <div class="defaultLoader">
#         </div>
#        </div>
#       </li>
#       <li class="Primarynavlinks" data-department="MEN">
#        <a class="PrimarynavlinksLink" data-link-id="02-03" data-link-name="MEN" href="/men" id="NI3" onclick="this.blur();TrackLinkID(this);" title="MEN">
#         <span class="PrimarynavlinksText" style="font-weight:bold!important;">
#          MEN
#         </span>
#        </a>
#        <div class="SecondaryDesktopNavigation SNDefaultNAV NavLoader nav-align-left" data-parentname="MEN">
#         <div class="defaultLoader">
#         </div>
#        </div>
#       </li>
#       <li class="Primarynavlinks" data-department="BOYS">
#        <a class="PrimarynavlinksLink" data-link-id="02-04" data-link-name="BOYS" href="/boys" id="NI4" onclick="this.blur();TrackLinkID(this);" title="BOYS">
#         <span class="PrimarynavlinksText" style="font-weight:bold!important;">
#          BOYS
#         </span>
#        </a>
#        <div class="SecondaryDesktopNavigation SNDefaultNAV NavLoader nav-align-left" data-parentname="BOYS">
#         <div class="defaultLoader">
#         </div>
#        </div>
#       </li>
#       <li class="Primarynavlinks" data-department="GIRLS">
#        <a class="PrimarynavlinksLink" data-link-id="02-05" data-link-name="GIRLS" href="/girls" id="NI5" onclick="this.blur();TrackLinkID(this);" title="GIRLS">
#         <span class="PrimarynavlinksText" style="font-weight:bold!important;">
#          GIRLS
#         </span>
#        </a>
#        <div class="SecondaryDesktopNavigation SNDefaultNAV NavLoader nav-align-left" data-parentname="GIRLS">
#         <div class="defaultLoader">
#         </div>
#        </div>
#       </li>
#       <li class="Primarynavlinks" data-department="BABY">
#        <a class="PrimarynavlinksLink" data-link-id="02-06" data-link-name="BABY" href="/newborn" id="NI6" onclick="this.blur();TrackLinkID(this);" title="BABY">
#         <span class="PrimarynavlinksText" style="font-weight:bold!important;">
#          BABY
#         </span>
#        </a>
#        <div class="SecondaryDesktopNavigation SNDefaultNAV NavLoader nav-align-left" data-parentname="BABY">
#         <div class="defaultLoader">
#         </div>
#        </div>
#       </li>
#       <li class="Primarynavlinks" data-department="LINGERIE">
#        <a class="PrimarynavlinksLink" data-link-id="02-07" data-link-name="LINGERIE" href="/lingerie-shop" id="NI7" onclick="this.blur();TrackLinkID(this);" title="LINGERIE">
#         <span class="PrimarynavlinksText" style="font-family:&amp;quot;Azo Sans&amp;quot;, AzoSans, sans-serif;!important;font-weight:bold!important;">
#          LINGERIE
#         </span>
#        </a>
#        <div class="SecondaryDesktopNavigation SNDefaultNAV NavLoader nav-align-left" data-parentname="LINGERIE">
#         <div class="defaultLoader">
#         </div>
#        </div>
#       </li>
#       <li class="Primarynavlinks" data-department="HOME">
#        <a class="PrimarynavlinksLink" data-link-id="02-08" data-link-name="HOME" href="/home" id="NI8" onclick="this.blur();TrackLinkID(this);" title="HOME">
#         <span class="PrimarynavlinksText" style="font-weight:bold!important;">
#          HOME
#         </span>
#        </a>
#        <div class="SecondaryDesktopNavigation SNDefaultNAV NavLoader nav-align-left" data-parentname="HOME">
#         <div class="defaultLoader">
#         </div>
#        </div>
#       </li>
#       <li class="Primarynavlinks" data-department="FURNITURE">
#        <a class="PrimarynavlinksLink" data-link-id="02-09" data-link-name="FURNITURE" href="/furniture" id="NI9" onclick="this.blur();TrackLinkID(this);" title="FURNITURE">
#         <span class="PrimarynavlinksText" style="font-weight:bold!important;">
#          FURNITURE
#         </span>
#        </a>
#        <div class="SecondaryDesktopNavigation SNDefaultNAV NavLoader nav-align-right" data-parentname="FURNITURE">
#         <div class="defaultLoader">
#         </div>
#        </div>
#       </li>
#       <li class="Primarynavlinks" data-department="BEAUTY">
#        <a class="PrimarynavlinksLink" data-link-id="02-10" data-link-name="BEAUTY" href="/beauty" id="NI10" onclick="this.blur();TrackLinkID(this);" title="BEAUTY">
#         <span class="PrimarynavlinksText" style="font-weight:bold!important;">
#          BEAUTY
#         </span>
#        </a>
#        <div class="SecondaryDesktopNavigation SNDefaultNAV NavLoader nav-align-right" data-parentname="BEAUTY">
#         <div class="defaultLoader">
#         </div>
#        </div>
#       </li>
#       <li class="Primarynavlinks" data-department="BRANDS">
#        <a class="PrimarynavlinksLink" data-link-id="02-11" data-link-name="BRANDS" href="/branded" id="NI11" onclick="this.blur();TrackLinkID(this);" title="BRANDS">
#         <span class="PrimarynavlinksText" style="font-weight:bold!important;">
#          BRANDS
#         </span>
#        </a>
#        <div class="SecondaryDesktopNavigation SNDefaultNAV NavLoader nav-align-right" data-parentname="BRANDS">
#         <div class="defaultLoader">
#         </div>
#        </div>
#       </li>
#       <li class="Primarynavlinks" data-department="SPORTS">
#        <a class="PrimarynavlinksLink" data-link-id="02-12" data-link-name="SPORTS" href="/sports" id="NI12" onclick="this.blur();TrackLinkID(this);" title="SPORTS">
#         <span class="PrimarynavlinksText" style="font-weight:bold!important;">
#          SPORTS
#         </span>
#        </a>
#        <div class="SecondaryDesktopNavigation SNDefaultNAV NavLoader nav-align-right" data-parentname="SPORTS">
#         <div class="defaultLoader">
#         </div>
#        </div>
#       </li>
#       <li class="Primarynavlinks" data-department="GIFTS &amp; FLOWERS">
#        <a class="PrimarynavlinksLink" data-link-id="02-13" data-link-name="GIFTS &amp; FLOWERS" href="/gift-ideas" id="NI13" onclick="this.blur();TrackLinkID(this);" title="GIFTS &amp; FLOWERS">
#         <span class="PrimarynavlinksText" style="font-weight:bold!important;">
#          GIFTS &amp; FLOWERS
#         </span>
#        </a>
#        <div class="SecondaryDesktopNavigation SNDefaultNAV NavLoader nav-align-right" data-parentname="GIFTS &amp; FLOWERS">
#         <div class="defaultLoader">
#         </div>
#        </div>
#       </li>
#       <li class="Primarynavlinks" data-department="CLEARANCE">
#        <a class="PrimarynavlinksLink" data-link-id="02-14" data-link-name="CLEARANCE" href="/clearance" id="NI14" onclick="this.blur();TrackLinkID(this);" title="CLEARANCE">
#         <span class="PrimarynavlinksText" style="color:#F28500;">
#          CLEARANCE
#         </span>
#        </a>
#        <div class="SecondaryDesktopNavigation SNDefaultNAV NavLoader nav-align-right" data-parentname="CLEARANCE">
#         <div class="defaultLoader">
#         </div>
#        </div>
#       </li>
#      </ul>
#     </div>
#    </nav>
#   </div>
#   <script>
#    var tempNav = document.getElementById("tempSEONavigation");
#     if (tempNav) {
#         document.querySelector(".PrimaryNavigation").outerHTML = tempNav.innerHTML;
#         tempNav.parentNode.removeChild(tempNav);
#     }
#   </script>
#   <script src="/scripts/bundles/jquery.js?v=pOerwTwapvpvIJvo5o4GYZ2qNdJ8SEnYkcp9LGmySo01?v=2020.1118.500.4" type="text/javascript">
#   </script>
#   <script src="/jscontent?v=2020.1118.500.4" type="text/javascript">
#   </script>
#   <script src="/jssettings?v=2020.1118.500.4" type="text/javascript">
#   </script>
#   <script src="/scripts/bundles/DesktopTray/js?v=oDxY-YN5okGQe7cXjJm-HQ6qn_LG5627W6jPlkvpxOw1">
#   </script>
#   <link href="/css/bundles/tray/css?v=460l7O85FFiXoueBbJLSjaE34ulfy301nvPEPOMrkZ01" rel="stylesheet"/>
#   <script id="tray-template" type="text/template">
#    <div id="mptErrorMsg" class="tray-loader-wrapper" style="display:none;">
#         <div class="errorMessageCon">
#             <p>Something Went Wrong</p>
#         </div>
#     </div>
#     <section id="tray-overlay" data-tray-id="placeholder">
#         <div id="background-overlay" class="tray-background"></div>
#         <div class="tray">
#             <div id="mptSpinner" class="tray-loader-wrapper">
#                 <div class="preloaderWrapper">
#                     <i class="nx-spinner"><span class="loaderContent">Loading</span></i>
#                 </div>
#             </div>
#             <header class="tray-header" draggable="true">
#                 <div id="headerTitleText" class="header-title">Default Header</div>
#                 <div class="close-tray close-text">Close</div>
#                 <span id="closeImage" class="close-tray sprite-sheet-close-icon"></span>
#             </header>
#             <section class="tray-content"></section>
#
#         </div>
#     </section>
#   </script>
#   <a id="nextpayapplynow" nx-tray="" nxtray-animation="slideInOutRight" nxtray-callback="CreditTrayUtilities.ProcessRequestAjax" nxtray-close-button="false" nxtray-content-method="replaced" nxtray-content-type=" ApplyNow" nxtray-content-url="" nxtray-credit-account-applied-for="NP" nxtray-header-title="" nxtray-id="nextpayapplynow" nxtray-tray-class="full-width bottom-tray" nxtray-tray-content-id="creditTrayContent" style="display:none">
#   </a>
#   <a id="next3stepapplynow" nx-tray="" nxtray-animation="slideInOutRight" nxtray-callback="CreditTrayUtilities.ProcessRequestAjax" nxtray-close-button="false" nxtray-content-method="replaced" nxtray-content-type=" ApplyNow" nxtray-content-url="" nxtray-credit-account-applied-for="NP3" nxtray-header-title="" nxtray-id="next3stepapplynow" nxtray-tray-class="full-width bottom-tray" nxtray-tray-content-id="creditTrayContent" style="display:none">
#   </a>
#   <a id="moreinfo" nx-tray="" nxtray-animation="slideInOutRight" nxtray-callback="CreditTrayUtilities.ProcessRequestAjax" nxtray-close-button="false" nxtray-content-method="replaced" nxtray-content-type="MoreInfo" nxtray-content-url="" nxtray-credit-account-applied-for="NP" nxtray-header-title="" nxtray-id="moreinfo" nxtray-tray-class="full-width bottom-tray" nxtray-tray-content-id="creditTrayContent" style="display:none">
#   </a>
#   <script type="text/javascript">
#    var jqueryUpgradeEnabledOnPage = true;
#   </script>
#   <script src="/scripts/bundles/jqueryupgrade.js?v=j8Jfxt3tn6mT9mt6JS0AX-yAExsoJCCisWxEz8KS87M1?v=2020.1118.500.4" type="text/javascript">
#   </script>
#   <script src="/scripts/bundles/libraries.js?v=f3vYx6c3dOiFkmuKDZnuRWGQv0j9Yne1bK0gKRDusqg1?v=2020.1118.500.4" type="text/javascript">
#   </script>
#   <script src="/scripts/bundles/modular/platmodcommon.js?v=T5wyNMFkFp6f1os6BITlptWH0vv3ToGek5-4RkR9knM1?v=2020.1118.500.4" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    SoftwareVersion = '2020.1118.500.4';
#     ThirdPartiesEnabled = true;
#
#
#
#     if (dataLayer != undefined) {
#         dataLayer.push({ 'domain_name': 'https://www.next.co.uk', 'settings_ga_id': 'UA-4131497-1', 'settings_ga_enabled': 'true', 'channel_country': 'United Kingdom', 'channel_country_code': 'GB', 'channel_currency_code': 'GBP', 'dmp_bluekai': 'False' });
#     }
#
#     try {
#             var CookieDomainName = '';
#             var ClassicGAEnabled = 'True';
#             GoogleAnalytics('UA-80755173-1');
#
#     } catch (e) { }
#
#     try {
#             GoogleTagManager('GTM-NJQQGW','');
#
#     } catch (e) { }
#
#     var BazaarVoiceEnabled = true;
#     var EnableFavourites = false;
#     var EnableItemLevelSingleProductPage = true;
#     var FeefoEnabled = true;
#     PageType = 'pageframe';
#     var CustomDropdownEnabled = true;
#   </script>
#   <script type="text/javascript">
#    var GeolocationAPIUrl = 'https://www.next.co.uk/geolocation-svc';
#   </script>
#   <script type="text/javascript">
#    var GeolocationVersion = 12;
#   </script>
#   <script type="text/javascript">
#    var isMobileSite = false;
#   </script>
#   <script src="/Scripts/CountryRedirect.js?v=2020.1118.500.4" type="text/javascript">
#   </script>
#   <div class="CSSLoadDetector">
#   </div>
#   <section class="ContentArea LargeHeader" id="ContentArea">
#    <section class="CurrentContent FirstLoad">
#     <div class="ppContainer" id="pri">
#      <link href="/css/bundles/modular/search-responsive.css?v=BNSKnW9F8KlNGJwkQ-yD51Z5lecb4Iipn5_pCDsOFzY1" rel="stylesheet"/>
#      <script src="/scripts/bundles/modular/searchjs.js?v=wfojk8WmjxjTis2aAGliJQgczn6Busqz9EgWt0zmoJ01">
#      </script>
#      <input class="br_data-cat_id" hidden="" title="no informative content" value="homewomen"/>
#      <input class="br_data-cat" hidden="" title="no informative content" value="home|women"/>
#      <!--Razor-->
#      <div id="rhsLoading">
#       <img alt="Loading..." src="/Images/Structural/Icons/Loaders/loader.gif"/>
#      </div>
#      <div class="OverflowFixer" id="search">
#       <div class="HeaderSpacer">
#       </div>
#       <div id="state">
#        <input id="siteUrl" type="hidden" value="//www.next.co.uk"/>
#        <input id="pageUrl" type="hidden" value="https://www.next.co.uk/shop/gender-women/sizetype-"/>
#        <input id="searchType" type="hidden" value="category"/>
#        <input id="freeTextSearchTerm" type="hidden" value=""/>
#        <input id="apiDomain" type="hidden" value="https://sliapi.next.co.uk/search"/>
#        <input id="itemsPerPageDefault" type="hidden" value="24"/>
#       </div>
#       <form action="#" autocomplete="off" class="fixedSearchResult" id="result" method="GET">
#        <div id="vertical-filters-container">
#         <input id="landingBaseUrl" type="hidden" value="{$landingBaseUrl}"/>
#         <script type="text/javascript">
#          AddDynamicResource("CSS", "/CSS/UI_Plugins.min.css");
#         AddDynamicResource("JS", "/ModularPLP/Desktop/scripts/UI_Plugins.js");
# ...
#                       Contact Us
#                      </a>
#                     </li>
#                     <li>
#                      <a aria-label="Accessible Site" class="footer112 footer142 footer144 components__MainListLink-h4vaug-1 GEzws footer135" data-testid="footer-main-links-accessible-site" href="https://accessible.next.co.uk" target="_blank">
#                       Accessible Site
#                      </a>
#                     </li>
#                     <li>
#                      <a aria-label="Website Accessibility Policy" class="footer112 footer142 footer144 components__MainListLink-h4vaug-1 GEzws footer135" data-testid="footer-main-links-website-accessibility-policy" href="https://www.next.co.uk/help/Faq/32625" target="_self">
#                       Website Accessibility Policy
#                      </a>
#                     </li>
#                     <li>
#                      <a aria-label="Accessibility In Our Stores" class="footer112 footer142 footer144 components__MainListLink-h4vaug-1 GEzws footer135" data-testid="footer-main-links-accessibility-in-our-stores" href="https://www.accessable.co.uk/organisations/next" target="_blank">
#                       Accessibility In Our Stores
#                      </a>
#                     </li>
#                     <li>
#                      <a aria-label="Site Map" class="footer112 footer142 footer144 components__MainListLink-h4vaug-1 GEzws footer135" data-testid="footer-main-links-site-map" href="https://www.next.co.uk/site-map" target="_self">
#                       Site Map
#                      </a>
#                     </li>
#                    </ul>
#                   </div>
#                  </div>
#                 </div>
#                </div>
#               </div>
#              </div>
#             </div>
#             <div class="footer1 footer3 footer47 footer66 footer80">
#              <div border="0.0625rem solid #eaeaea" class="footer167 footer163 sc-AxirZ qyDuo footer171" data-testid="footer-main-links-accordions-shopping-with-us" titlecolor="#000000">
#               <div aria-disabled="false" aria-expanded="false" class="footer205 footer199 footer195" role="button" tabindex="0">
#                <div class="footer203 footer196">
#                 <h2 class="footer112 sc-AxjAm llesPH footer120" titlecolor="#000000">
#                  Shopping With Us
#                 </h2>
#                </div>
#                <div aria-disabled="false" aria-hidden="true" class="footer205 footer208 footer204 footer197 footer210">
#                 <span class="footer216">
#                  <img alt="Accordion chevron icon" src="https://xcdn.next.co.uk/content/platmod/icons/shared/chevron.svg"/>
#                 </span>
#                </div>
#               </div>
#               <div class="footer217 footer219" style="min-height:0px">
#                <div class="footer220">
#                 <div class="footer221">
#                  <div role="region">
#                   <div class="footer222 sc-AxiKw eSbheu">
#                    <ul class="components__MainList-h4vaug-0 kQCkHz" data-testid="footer-main-links-title-shopping-with-us-list">
#                     <li>
#                      <a aria-label="Next Unlimited" class="footer112 footer142 footer144 components__MainListLink-h4vaug-1 GEzws footer135" data-testid="footer-main-links-next-unlimited" href="https://www.next.co.uk/unlimited" target="_self">
#                       Next Unlimited
#                      </a>
#                     </li>
#                     <li>
#                      <a aria-label="NextPay Credit Account" class="footer112 footer142 footer144 components__MainListLink-h4vaug-1 GEzws footer135" data-testid="footer-main-links-nextpay-credit-account" href="https://www.next.co.uk/credit" target="_self">
#                       NextPay Credit Account
#                      </a>
#                     </li>
#                     <li>
#                      <a aria-label="Evouchers" class="footer112 footer142 footer144 components__MainListLink-h4vaug-1 GEzws footer135" data-testid="footer-main-links-evouchers" href="https://www.next.co.uk/evouchers" target="_self">
#                       Evouchers
#                      </a>
#                     </li>
#                     <li>
#                      <a aria-label="Gift Cards" class="footer112 footer142 footer144 components__MainListLink-h4vaug-1 GEzws footer135" data-testid="footer-main-links-gift-cards" href="https://flowers.next.co.uk/gift-cards" target="_blank">
#                       Gift Cards
#                      </a>
#                     </li>
#                     <li>
#                      <a aria-label="Gift Experiences" class="footer112 footer142 footer144 components__MainListLink-h4vaug-1 GEzws footer135" data-testid="footer-main-links-gift-experiences" href="https://www.next.co.uk/shop/department-homeware-category-giftexperiences-0" target="_self">
#                       Gift Experiences
#                      </a>
#                     </li>
#                     <li>
#                      <a aria-label="Flowers, Plants &amp; Wine" class="footer112 footer142 footer144 components__MainListLink-h4vaug-1 GEzws footer135" data-testid="footer-main-links-flowers,-plants-&amp;-wine" href="https://flowers.next.co.uk" target="_blank">
#                       Flowers, Plants &amp; Wine
#                      </a>
#                     </li>
#                    </ul>
#                   </div>
#                  </div>
#                 </div>
#                </div>
#               </div>
#              </div>
#             </div>
#             <div class="footer1 footer3 footer47 footer66 footer80">
#              <div border="0.0625rem solid #eaeaea" class="footer167 footer163 sc-AxirZ qyDuo footer171" data-testid="footer-main-links-accordions-privacy-&amp;-legal" titlecolor="#000000">
#               <div aria-disabled="false" aria-expanded="false" class="footer205 footer199 footer195" role="button" tabindex="0">
#                <div class="footer203 footer196">
#                 <h2 class="footer112 sc-AxjAm llesPH footer120" titlecolor="#000000">
#                  Privacy &amp; Legal
#                 </h2>
#                </div>
#                <div aria-disabled="false" aria-hidden="true" class="footer205 footer208 footer204 footer197 footer210">
#                 <span class="footer216">
#                  <img alt="Accordion chevron icon" src="https://xcdn.next.co.uk/content/platmod/icons/shared/chevron.svg"/>
#                 </span>
#                </div>
#               </div>
#               <div class="footer217 footer219" style="min-height:0px">
#                <div class="footer220">
#                 <div class="footer221">
#                  <div role="region">
#                   <div class="footer222 sc-AxiKw eSbheu">
#                    <ul class="components__MainList-h4vaug-0 kQCkHz" data-testid="footer-main-links-title-privacy-&amp;-legal-list">
#                     <li>
#                      <a aria-label="Cookies &amp; Privacy Policy" class="footer112 footer142 footer144 components__MainListLink-h4vaug-1 GEzws footer135" data-testid="footer-main-links-cookies-&amp;-privacy-policy" href="https://www.next.co.uk/privacy" target="_self">
#                       Cookies &amp; Privacy Policy
#                      </a>
#                     </li>
#                     <li>
#                      <a aria-label="Terms &amp; Conditions" class="footer112 footer142 footer144 components__MainListLink-h4vaug-1 GEzws footer135" data-testid="footer-main-links-terms-&amp;-conditions" href="https://www.next.co.uk/terms" target="_self">
#                       Terms &amp; Conditions
#                      </a>
#                     </li>
#                    </ul>
#                   </div>
#                  </div>
#                 </div>
#                </div>
#               </div>
#              </div>
#             </div>
#             <div class="footer1 footer3 footer47 footer66 footer80">
#              <div border="0.0625rem solid #eaeaea" class="footer167 footer163 sc-AxirZ qyDuo footer171" data-testid="footer-main-links-accordions-more-from-next" titlecolor="#000000">
#               <div aria-disabled="false" aria-expanded="false" class="footer205 footer199 footer195" role="button" tabindex="0">
#                <div class="footer203 footer196">
#                 <h2 class="footer112 sc-AxjAm llesPH footer120" titlecolor="#000000">
#                  More From Next
#                 </h2>
#                </div>
#                <div aria-disabled="false" aria-hidden="true" class="footer205 footer208 footer204 footer197 footer210">
#                 <span class="footer216">
#                  <img alt="Accordion chevron icon" src="https://xcdn.next.co.uk/content/platmod/icons/shared/chevron.svg"/>
#                 </span>
#                </div>
#               </div>
#               <div class="footer217 footer219" style="min-height:0px">
#                <div class="footer220">
#                 <div class="footer221">
#                  <div role="region">
#                   <div class="footer222 sc-AxiKw eSbheu">
#                    <ul class="components__MainList-h4vaug-0 kQCkHz" data-testid="footer-main-links-title-more-from-next-list">
#                     <li>
#                      <a aria-label="Next App" class="footer112 footer142 footer144 components__MainListLink-h4vaug-1 GEzws footer135" data-testid="footer-main-links-next-app" href="https://www.next.co.uk/apps" target="_blank">
#                       Next App
#                      </a>
#                     </li>
#                     <li>
#                      <a aria-label="The Company" class="footer112 footer142 footer144 components__MainListLink-h4vaug-1 GEzws footer135" data-testid="footer-main-links-the-company" href="http://www.nextplc.co.uk" target="_blank">
#                       The Company
#                      </a>
#                     </li>
#                     <li>
#                      <a aria-label="Media &amp; Press" class="footer112 footer142 footer144 components__MainListLink-h4vaug-1 GEzws footer135" data-testid="footer-main-links-media-&amp;-press" href="https://www.nextplc.co.uk/media/media-contacts" target="_blank">
#                       Media &amp; Press
#                      </a>
#                     </li>
#                     <li>
#                      <a aria-label="Business 2 Business" class="footer112 footer142 footer144 components__MainListLink-h4vaug-1 GEzws footer135" data-testid="footer-main-links-business-2-business" href="http://b2b.next.co.uk" target="_blank">
#                       Business 2 Business
#                      </a>
#                     </li>
#                     <li>
#                      <a aria-label="Next Franchise" class="footer112 footer142 footer144 components__MainListLink-h4vaug-1 GEzws footer135" data-testid="footer-main-links-next-franchise" href="https://www.next.co.uk/next-franchise/" target="_blank">
#                       Next Franchise
#                      </a>
#                     </li>
#                     <li>
#                      <a aria-label="Careers @ Next" class="footer112 footer142 footer144 components__MainListLink-h4vaug-1 GEzws footer135" data-testid="footer-main-links-careers-@-next" href="https://careers.next.co.uk" target="_blank">
#                       Careers @ Next
#                      </a>
#                     </li>
#                     <li>
#                      <a aria-label="View Our Modern Slavery Statement" class="footer112 footer142 footer144 components__MainListLink-h4vaug-1 GEzws footer135" data-testid="footer-main-links-view-our-modern-slavery-statement" href="https://www.nextplc.co.uk/~/media/Files/N/Next-PLC-V2/documents/corporate-responsibility/human-rights-and-modern-slavery-2019.pdf" target="_blank">
#                       View Our Modern Slavery Statement
#                      </a>
#                     </li>
#                     <li>
#                      <a aria-label="Corporate Responsibility Report" class="footer112 footer142 footer144 components__MainListLink-h4vaug-1 GEzws footer135" data-testid="footer-main-links-corporate-responsibility-report" href="https://www.nextplc.co.uk/~/media/Files/N/Next-PLC-V2/documents/cr-reports/cr-2019.pdf" target="_blank">
#                       Corporate Responsibility Report
#                      </a>
#                     </li>
#                    </ul>
#                   </div>
#                  </div>
#                 </div>
#                </div>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="footer1 components__RegionGrid-sc-1m26iat-1 bEjkXl Copyright footer2" data-testid="footer-region-copyright">
#          <div class="footer104 components__RegionContainer-sc-1m26iat-0 aiAcX footer111" isinternationalcountry="false">
#           <div class="footer1 components__GridContainer-sc-1rhhu64-1 hkepww footer2 footer5 footer10">
#            <div class="footer1 components__ChildGrid-sc-1rhhu64-2 dtvbVu footer3 footer47">
#             <a class="components__DeviceToggleLink-sc-1rhhu64-3 gsOtnZ" data-testid="footer-copyright-switcher-mobiletoggle" href="">
#              View mobile site
#             </a>
#            </div>
#            <div class="footer1 components__ChildGrid-sc-1rhhu64-2 dtvbVu footer3 footer47">
#             <h6 class="footer112 components__CopyrightText-sc-1rhhu64-0 hvtxZc footer123" data-testid="footer-copyright-text">
#              © 2020 Next Retail Ltd. All rights reserved.
#             </h6>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </footer>
#      </section>
#     </div>
#    </div>
#    <script>
#     !function(i){function e(e){for(var t,r,n=e[0],o=e[1],u=e[2],f=0,l=[];f<n.length;f++)r=n[f],Object.prototype.hasOwnProperty.call(p,r)&&p[r]&&l.push(p[r][0]),p[r]=0;for(t in o)Object.prototype.hasOwnProperty.call(o,t)&&(i[t]=o[t]);for(s&&s(e);l.length;)l.shift()();return c.push.apply(c,u||[]),a()}function a(){for(var e,t=0;t<c.length;t++){for(var r=c[t],n=!0,o=1;o<r.length;o++){var u=r[o];0!==p[u]&&(n=!1)}n&&(c.splice(t--,1),e=f(f.s=r[0]))}return e}var r={},p={1:0},c=[];function f(e){if(r[e])return r[e].exports;var t=r[e]={i:e,l:!1,exports:{}};return i[e].call(t.exports,t,t.exports,f),t.l=!0,t.exports}f.m=i,f.c=r,f.d=function(e,t,r){f.o(e,t)||Object.defineProperty(e,t,{enumerable:!0,get:r})},f.r=function(e){"undefined"!=typeof Symbol&&Symbol.toStringTag&&Object.defineProperty(e,Symbol.toStringTag,{value:"Module"}),Object.defineProperty(e,"__esModule",{value:!0})},f.t=function(t,e){if(1&e&&(t=f(t)),8&e)return t;if(4&e&&"object"==typeof t&&t&&t.__esModule)return t;var r=Object.create(null);if(f.r(r),Object.defineProperty(r,"default",{enumerable:!0,value:t}),2&e&&"string"!=typeof t)for(var n in t)f.d(r,n,function(e){return t[e]}.bind(null,n));return r},f.n=function(e){var t=e&&e.__esModule?function(){return e.default}:function(){return e};return f.d(t,"a",t),t},f.o=function(e,t){return Object.prototype.hasOwnProperty.call(e,t)},f.p="https://www.next.co.uk/footerstatic/";var t=window["webpackJsonpnext-footer"]=window["webpackJsonpnext-footer"]||[],n=t.push.bind(t);t.push=e,t=t.slice();for(var o=0;o<t.length;o++)e(t[o]);var s=n;a()}([])
#    </script>
#   </div>
#   <script type="text/javascript">
#    var _cf = _cf || []; _cf.push(['_setFsp', true]);  _cf.push(['_setBm', true]);  _cf.push(['_setAu', '/assets/6a9693d0ui2266a6cd2cda95e76539']);
#   </script>
#   <script src="/assets/6a9693d0ui2266a6cd2cda95e76539" type="text/javascript">
#   </script>
#  </body>
#  <script nomodule="" src="https://xcdn.next.co.uk/content/platmod/vendors/core-js/2.6.11/core.min.js">
#  </script>
#  <script src="https://xcdn.next.co.uk/content/platmod/vendors/react/16.13.1/umd/react.production.min.js">
#  </script>
#  <script src="https://xcdn.next.co.uk/content/platmod/vendors/react/16.13.1/umd/react-dom.production.min.js">
#  </script>
#  <script src="https://www.next.co.uk/footerstatic/static/js/2.1.5.11.chunk.js">
#  </script>
#  <script src="https://www.next.co.uk/footerstatic/static/js/main.1.5.11.chunk.js">
#  </script>
# </html>

# %% [markdown]
# ### Retrieve all women's products

# %%
all_clothing_womens = soup.find_all('article', class_='Item Fashion')
product_one = all_clothing_womens[0] 
product_one # Preview the first entry
# Out:
# <article class="Item Fashion" data-brand="Next" data-colour="Black" data-department="Womenswear" data-itemnumber="201339" data-itemposition="1" id="i1">
# <section class="Details firstRow">
# <div class="Info">
# <h2 class="Title">
# <a class="TitleText" data-desc="Black Super Stretch Soft Sculpt Pull-On Denim Leggings" data-label="Black Super Stretch Soft Sculpt Pull-On Denim Leggings" data-usespan="False" href="//www.next.co.uk/g9434s13/201339#201339" title="Black Super Stretch Soft Sculpt Pull-On Denim Leggings">
# <span class="Desc">
#                             Black Super Stretch Soft Sculpt Pull-On Denim Leggings
#                         </span>
# </a>
# </h2>
# <div class="Price">
# <a href="//www.next.co.uk/g9434s13/201339#201339" title="Black Super Stretch Soft Sculpt Pull-On Denim Leggings">
# £22                        </a>
# </div>
# <div class="Rating rating-50">
# <a href="//www.next.co.uk/g9434s13/201339#201339" title="Black Super Stretch Soft Sculpt Pull-On Denim Leggings">
# </a>
# </div>
# <div class="ColourExpander Closed">
# <ul class="Colours">
# <li class="Colour Selected Primary" data-brand="Next" data-debug="Primary">
# <a href="/g9434s13/201339#201339" title="Black">
# <img alt="Black" data-alt="Black Super Stretch Soft Sculpt Pull-On Denim Leggings (201339) | £22" data-colour="Black" data-desc="Black Super Stretch Soft Sculpt Pull-On Denim Leggings" data-isdiscount="" data-isnew="" data-issale="false" data-itemfit="Reg/Long/XL Tall" data-itemnumber="201339" data-petitelogo="" data-pluslogo="" data-price="£22" data-rating="5" data-salehighlightprice="" data-saleplainprice="" data-saleshownowpricebeforewasprice="" data-search-image="https://xcdn.next.co.uk/Common/Items/Default/Default/ItemImages/Search/224x336/201339.jpg" data-showwasprice="" data-talllogo="https://xcdn.next.co.uk/Common/Items/Default/Default/Logos/NEXT_GB/en-gb/14/tall.png" data-title="Black Super Stretch Soft Sculpt Pull-On Denim Leggings" data-type="Fashion" data-url="g9434s13/201339#201339" src="https://xcdn.next.co.uk/Common/Items/Default/Default/ItemImages/AltItemSwatch/21x21/201339.jpg" title="Black"/>
# </a>
# </li>
# <li class="Colour" data-brand="Next" data-debug="Alternate">
# <a href="/g8168s9/455847#455847" title="Berry">
# <img alt="Berry" data-alt="Berry Super Stretch Soft Sculpt Pull-On Denim Leggings (455847) | £22" data-colour="Berry" data-desc="Berry Super Stretch Soft Sculpt Pull-On Denim Leggings" data-isdiscount="" data-isnew="False" data-issale="false" data-itemfit="Reg/Long/XL Tall" data-itemnumber="455847" data-petitelogo="" data-pluslogo="" data-price="£22" data-rating="4" data-salehighlightprice="" data-saleplainprice="" data-saleshownowpricebeforewasprice="" data-search-image="https://xcdn.next.co.uk/Common/Items/Default/Default/ItemImages/Search/224x336/455847.jpg" data-showwasprice="" data-talllogo="https://xcdn.next.co.uk/Common/Items/Default/Default/Logos/NEXT_GB/en-gb/14/tall.png" data-title="Berry Super Stretch Soft Sculpt Pull-On Denim Leggings" data-type="Fashion" data-url="g8168s9/455847#455847" src="https://xcdn.next.co.uk/Common/Items/Default/Default/ItemImages/AltItemSwatch/21x21/455847.jpg" title="Berry"/>
# </a>
# </li>
# <li class="Colour" data-brand="Next" data-debug="Alternate">
# <a href="/g8168s1/643607#643607" title="Black Denim">
# <img alt="Black Denim" data-alt="Black Denim Super Stretch Soft Sculpt Pull-On Denim Leggings (643607) | £22" data-colour="Black Denim" data-desc="Black Denim Super Stretch Soft Sculpt Pull-On Denim Leggings" data-isdiscount="" data-isnew="False" data-issale="false" data-itemfit="Reg/Long/XL Tall" data-itemnumber="643607" data-petitelogo="" data-pluslogo="" data-price="£22" data-rating="3.5" data-salehighlightprice="" data-saleplainprice="" data-saleshownowpricebeforewasprice="" data-search-image="https://xcdn.next.co.uk/Common/Items/Default/Default/ItemImages/Search/224x336/643607.jpg" data-showwasprice="" data-talllogo="https://xcdn.next.co.uk/Common/Items/Default/Default/Logos/NEXT_GB/en-gb/14/tall.png" data-title="Black Denim Super Stretch Soft Sculpt Pull-On Denim Leggings" data-type="Fashion" data-url="g8168s1/643607#643607" src="https://xcdn.next.co.uk/Common/Items/Default/Default/ItemImages/AltItemSwatch/21x21/643607.jpg" title="Black Denim"/>
# </a>
# </li>
# <li class="Colour" data-brand="Next" data-debug="Alternate">
# <a href="/style/st393287/923569#923569" title="Dark">
# <img alt="Dark" data-alt="Dark Super Stretch Soft Sculpt Pull-On Denim Leggings (923569) | £22" data-colour="Dark" data-desc="Dark Super Stretch Soft Sculpt Pull-On Denim Leggings" data-isdiscount="" data-isnew="False" data-issale="false" data-itemfit="Reg/Long/XL Tall" data-itemnumber="923569" data-petitelogo="" data-pluslogo="" data-price="£22" data-rating="4" data-salehighlightprice="" data-saleplainprice="" data-saleshownowpricebeforewasprice="" data-search-image="https://xcdn.next.co.uk/Common/Items/Default/Default/ItemImages/Search/224x336/923569.jpg" data-showwasprice="" data-talllogo="https://xcdn.next.co.uk/Common/Items/Default/Default/Logos/NEXT_GB/en-gb/14/tall.png" data-title="Dark Super Stretch Soft Sculpt Pull-On Denim Leggings" data-type="Fashion" data-url="style/st393287/923569#923569" src="https://xcdn.next.co.uk/Common/Items/Default/Default/ItemImages/AltItemSwatch/21x21/923569.jpg" title="Dark"/>
# </a>
# </li>
# <li class="Colour" data-brand="Next" data-debug="Alternate">
# <a href="/style/st393287/436703#436703" title="Dark Blue">
# <img alt="Dark Blue" data-alt="Dark Blue Super Stretch Soft Sculpt Pull-On Denim Leggings (436703) | £22" data-colour="Dark Blue" data-desc="Dark Blue Super Stretch Soft Sculpt Pull-On Denim Leggings" data-isdiscount="" data-isnew="False" data-issale="false" data-itemfit="Reg/Long/XL Tall" data-itemnumber="436703" data-petitelogo="" data-pluslogo="" data-price="£22" data-rating="5" data-salehighlightprice="" data-saleplainprice="" data-saleshownowpricebeforewasprice="" data-search-image="https://xcdn.next.co.uk/Common/Items/Default/Default/ItemImages/Search/224x336/436703.jpg" data-showwasprice="" data-talllogo="https://xcdn.next.co.uk/Common/Items/Default/Default/Logos/NEXT_GB/en-gb/14/tall.png" data-title="Dark Blue Super Stretch Soft Sculpt Pull-On Denim Leggings" data-type="Fashion" data-url="style/st393287/436703#436703" src="https://xcdn.next.co.uk/Common/Items/Default/Default/ItemImages/AltItemSwatch/21x21/436703.jpg" title="Dark Blue"/>
# </a>
# </li>
# <li class="Colour" data-brand="Next" data-debug="Alternate">
# <a href="/g9424s11/387611#387611" title="Dark Wash">
# <img alt="Dark Wash" data-alt="Dark Wash Super Stretch Soft Sculpt Pull-On Denim Leggings (387611) | £22" data-colour="Dark Wash" data-desc="Dark Wash Super Stretch Soft Sculpt Pull-On Denim Leggings" data-isdiscount="" data-isnew="False" data-issale="false" data-itemfit="Reg/Long/XL Tall" data-itemnumber="387611" data-petitelogo="" data-pluslogo="" data-price="£22" data-rating="4" data-salehighlightprice="" data-saleplainprice="" data-saleshownowpricebeforewasprice="" data-search-image="https://xcdn.next.co.uk/Common/Items/Default/Default/ItemImages/Search/224x336/387611.jpg" data-showwasprice="" data-talllogo="https://xcdn.next.co.uk/Common/Items/Default/Default/Logos/NEXT_GB/en-gb/14/tall.png" data-title="Dark Wash Super Stretch Soft Sculpt Pull-On Denim Leggings" data-type="Fashion" data-url="g9424s11/387611#387611" src="https://xcdn.next.co.uk/Common/Items/Default/Default/ItemImages/AltItemSwatch/21x21/387611.jpg" title="Dark Wash"/>
# </a>
# </li>
# <li class="Colour" data-brand="Next" data-debug="Alternate">
# <a href="/g9430s3/878225#878225" title="Mid Blue">
# <img alt="Mid Blue" data-alt="Mid Blue Super Stretch Soft Sculpt Pull-On Denim Leggings (878225) | £22" data-colour="Mid Blue" data-desc="Mid Blue Super Stretch Soft Sculpt Pull-On Denim Leggings" data-isdiscount="" data-isnew="False" data-issale="false" data-itemfit="Reg/Long/XL Tall" data-itemnumber="878225" data-petitelogo="" data-pluslogo="" data-price="£22" data-rating="4.5" data-salehighlightprice="" data-saleplainprice="" data-saleshownowpricebeforewasprice="" data-search-image="https://xcdn.next.co.uk/Common/Items/Default/Default/ItemImages/Search/224x336/878225.jpg" data-showwasprice="" data-talllogo="https://xcdn.next.co.uk/Common/Items/Default/Default/Logos/NEXT_GB/en-gb/14/tall.png" data-title="Mid Blue Super Stretch Soft Sculpt Pull-On Denim Leggings" data-type="Fashion" data-url="g9430s3/878225#878225" src="https://xcdn.next.co.uk/Common/Items/Default/Default/ItemImages/AltItemSwatch/21x21/878225.jpg" title="Mid Blue"/>
# </a>
# </li>
# <li class="ClearBoth">
# </li>
# </ul>
# </div>
# <div class="ColourExpanderControl">
# </div>
# </div>
# <div class="Images">
# <a class="Image" href="//www.next.co.uk/g9434s13/201339#201339" title="Super Stretch Soft Sculpt Pull-On Denim Leggings">
# <img alt="Super Stretch Soft Sculpt Pull-On Denim Leggings" src="https://xcdn.next.co.uk/Common/Items/Default/Default/ItemImages/Search/224x336/201339.jpg?X56"/>
# </a>
# <div class="Overlay Banner">
# </div>
# <div class="Overlay Logos">
# <img alt="I'm available in tall sizes" class="Logo channelisedLogo" src="https://xcdn.next.co.uk/Common/Items/Default/Default/Logos/NEXT_GB/en-gb/14/tall.png"/>
# </div>
# </div>
# </section>
# </article>

# %% [markdown]
# ### Find the title of product one

# %%
product_one.find("h2", class_="Title")
# Out:
# <h2 class="Title">
# <a class="TitleText" data-desc="Black Super Stretch Soft Sculpt Pull-On Denim Leggings" data-label="Black Super Stretch Soft Sculpt Pull-On Denim Leggings" data-usespan="False" href="//www.next.co.uk/g9434s13/201339#201339" title="Black Super Stretch Soft Sculpt Pull-On Denim Leggings">
# <span class="Desc">
#                             Black Super Stretch Soft Sculpt Pull-On Denim Leggings
#                         </span>
# </a>
# </h2>

# %%
product_one.find('a')
# Out:
# <a class="TitleText" data-desc="Black Super Stretch Soft Sculpt Pull-On Denim Leggings" data-label="Black Super Stretch Soft Sculpt Pull-On Denim Leggings" data-usespan="False" href="//www.next.co.uk/g9434s13/201339#201339" title="Black Super Stretch Soft Sculpt Pull-On Denim Leggings">
# <span class="Desc">
#                             Black Super Stretch Soft Sculpt Pull-On Denim Leggings
#                         </span>
# </a>

# %%
product_one_title = product_one.find('a').attrs['title']
product_one_title
# Out:
# 'Black Super Stretch Soft Sculpt Pull-On Denim Leggings'

# %% [markdown]
# ### Find the price of product one

# %%
product_one.find("div", class_="Price")
# Out:
# <div class="Price">
# <a href="//www.next.co.uk/g9434s13/201339#201339" title="Black Super Stretch Soft Sculpt Pull-On Denim Leggings">
# £22                        </a>
# </div>

# %%
product_one.find("div", class_="Price").find('a')
# Out:
# <a href="//www.next.co.uk/g9434s13/201339#201339" title="Black Super Stretch Soft Sculpt Pull-On Denim Leggings">
# £22                        </a>

# %%
product_one.find("div", class_="Price").find('a').text
# Out:
# '\r\n£22                        '

# %%
product_one.find("div", class_="Price").find('a').text.strip()
# Out:
# '£22'

# %%
product_one_price = product_one.find("div", class_="Price").find('a').text.strip().strip('£')
product_one_price
# Out:
# '22'

# %% [markdown]
# ### Get Product Name

# %%
def retrive_first_product_price():
    # Retrieve all products
    all_products = soup.find_all('article', class_='Item Fashion')
    # Pick out the first product
    product_one = all_products[0]
    # Pick out the price of the first product, which is in the strong tag
    product_one_price = product_one.find("strong")
    
    # Print the result
    print('Product Price: {}'.format(product_one_price.get_text()))
    # Remove the $ sign
    print(product_one_price.get_text().strip().strip('$'))

if __name__ == '__main__':
    retrive_first_product_price()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-395954cd3b34> in <module>
#      13
#      14 if __name__ == '__main__':
# ---> 15     retrive_first_product_price()
#
# <ipython-input-20-395954cd3b34> in retrive_first_product_price()
#       8
#       9     # Print the result
# ---> 10     print('Product Price: {}'.format(product_one_price.get_text()))
#      11     # Remove the $ sign
#      12     print(product_one_price.get_text().strip().strip('$'))
#
# AttributeError: 'NoneType' object has no attribute 'get_text'

# %% [markdown]
# ### Build Dictionary of product names and prices

# %%
def product_prices():
    # Retrieve all products
    all_products = soup.find_all('article', class_='Item Fashion')
    # Empty Dictionary
    products = []

    # Build Dictionary with key as name of each product, which is under the "p" tag. and value as the price
    
    for product in all_products:
        name_and_price = {}
        name_and_price['Name'] = product.find("a").attrs['title']
        name_and_price['Price'] = int(product.find("div", class_="Price").find('a').text.strip().strip('£'))
        products.append(name_and_price)
        #         products[product.find("a").attrs['title']] = [int(product.find("div", class_="Price").find('a').text.strip().strip('£'))]
    
    # Sort by name
#     products_sorted = dict(sorted(products.items(), key=lambda item: item[1]))
    
    return products

# %%
product_prices()
# Out:
# [{'Name': 'Black Super Stretch Soft Sculpt Pull-On Denim Leggings',
#   'Price': 22},
#  {'Name': 'Black Oversized Soft Shacket', 'Price': 20},
#  {'Name': 'Black Tree Graphic Christmas Sweatshirt', 'Price': 25},
#  {'Name': 'Light Pink Womens Christmas Jumper', 'Price': 34},
#  {'Name': 'Black Teddy Borg Coat', 'Price': 68},
#  {'Name': 'Khaki Emma Willis Rib High Neck Jumper', 'Price': 34},
#  {'Name': 'Black Womens Christmas Jumper', 'Price': 30},
#  {'Name': 'Black/Red Womens Christmas Jumper', 'Price': 30},
#  {'Name': 'Red Padded Coat', 'Price': 50},
#  {'Name': 'Oatmeal Tree Graphic Christmas Sweatshirt', 'Price': 26},
#  {'Name': 'Black Roll Neck Dress', 'Price': 35},
#  {'Name': 'Charcoal Rainbow Cotton Blend Pyjamas', 'Price': 25},
#  {'Name': 'Black Embellished Star Dolman Long Sleeve Top', 'Price': 18},
#  {'Name': 'Black Forever Comfort® Rider Knee High Material Mix Boots',
#   'Price': 56},
#  {'Name': 'Nike Run Black/Gold Revolution 5 Premium Trainers', 'Price': 48},
#  {'Name': 'Red Womens Christmas Jumper', 'Price': 32},
#  {'Name': 'Khaki Jersey Denim Joggers', 'Price': 28},
#  {'Name': 'Black Full Length Leggings', 'Price': 10},
#  {'Name': 'Blue Stars Tunic And Legging Pyjama Set', 'Price': 28},
#  {'Name': 'Dark Blue Elasticated Waist Tapered Jeans', 'Price': 28},
#  {'Name': 'Red Stitch Detail Cosy Jumper', 'Price': 20},
#  {'Name': 'Neutral Emma Willis Rib High Neck Jumper', 'Price': 34},
#  {'Name': 'Grey Heart Stripe Jumper', 'Price': 28},
#  {'Name': 'Pink Womens Christmas Jumper', 'Price': 30}]

# %%
df = pd.DataFrame.from_dict(product_prices())
df
# Out:
#                                                  Name  Price
# 0   Black Super Stretch Soft Sculpt Pull-On Denim ...     22
# 1                        Black Oversized Soft Shacket     20
# 2             Black Tree Graphic Christmas Sweatshirt     25
# 3                  Light Pink Womens Christmas Jumper     34
# 4                               Black Teddy Borg Coat     68
# 5              Khaki Emma Willis Rib High Neck Jumper     34
# 6                       Black Womens Christmas Jumper     30
# 7                   Black/Red Womens Christmas Jumper     30
# 8                                     Red Padded Coat     50
# 9           Oatmeal Tree Graphic Christmas Sweatshirt     26
# 10                              Black Roll Neck Dress     35
# 11              Charcoal Rainbow Cotton Blend Pyjamas     25
# 12      Black Embellished Star Dolman Long Sleeve Top     18
# 13  Black Forever Comfort® Rider Knee High Materia...     56
# 14  Nike Run Black/Gold Revolution 5 Premium Trainers     48
# 15                        Red Womens Christmas Jumper     32
# 16                         Khaki Jersey Denim Joggers     28
# 17                         Black Full Length Leggings     10
# 18            Blue Stars Tunic And Legging Pyjama Set     28
# 19          Dark Blue Elasticated Waist Tapered Jeans     28
# 20                      Red Stitch Detail Cosy Jumper     20
# 21           Neutral Emma Willis Rib High Neck Jumper     34
# 22                           Grey Heart Stripe Jumper     28
# 23                       Pink Womens Christmas Jumper     30
